# %%
import time

print('PIENSA EN UN NÚMERO CUALQUIERA \n')
time.sleep(8)
print('MULTIPLICA ESE NÚMERO POR DOS (2) \n')
time.sleep(8)
print('AHORA SÚMALE SEIS (6) \n')
time.sleep(8)
print('DIVIDELO ENTRE DOS (2) \n')
time.sleep(8)
print('AHORA, RÉSTALE EL NÚMERO QUE PENSASTE \n')
time.sleep(8)
print('ESTOY CASI SEGURO QUE EL NÚMERO QUE PENSASTE ES TRES (3) ')
# Out:
# PIENSA EN UN NÚMERO CUALQUIERA
#
# MULTIPLICA ESE NÚMERO POR DOS (2)
#
# AHORA SÚMALE SEIS (6)
#
# DIVIDELO ENTRE DOS (2)
#
# AHORA, RÉSTALE EL NÚMERO QUE PENSASTE
#
# ESTOY CASI SEGURO QUE EL NÚMERO QUE PENSASTE ES TRES (3)
